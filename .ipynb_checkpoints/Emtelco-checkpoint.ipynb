# %% [markdown]
# ####     Emtelco entrevista

# %%
# Pandas para lectura de archivo
import pandas as pd
# Carga el archivo CSV en un DataFrame
datos = pd.read_excel('datos.xlsx')

# %%
# Miremos una descripción del set de datos.
datos.describe(include='all')
# Out:
#                                 Fecha  ID de respuesta Nombre del cliente  \
# count                              70        70.000000                 70
# unique                            NaN              NaN                 70
# top                               NaN              NaN          cliente 1
# freq                              NaN              NaN                  1
# mean    2023-11-30 18:49:29.692642560        35.500000                NaN
# min        2023-11-16 13:30:31.585000         1.000000                NaN
# 25%     2023-11-23 15:16:25.674750208        18.250000                NaN
# 50%     2023-11-28 18:38:49.268500224        35.500000                NaN
# 75%     2023-12-05 05:22:21.408499968        52.750000                NaN
# max        2023-12-24 19:05:55.920000        70.000000                NaN
# std                               NaN        20.351085                NaN
#
#        Canal envio Idioma del usuario  \
# count           70                 70
# unique           1                  1
# top          email                 ES
# freq            70                 70
# mean           NaN                NaN
# min            NaN                NaN
# 25%            NaN                NaN
# 50%            NaN                NaN
# 75%            NaN                NaN
# max            NaN                NaN
# std            NaN                NaN
#
#         importancia_conocimiento_de_marcas: donde 1 es lo mas importante y 4 no lo consideras importante  \
# count                                           69.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             2.188406
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              2.000000
# 75%                                              3.000000
# max                                              4.000000
# std                                              1.088379
#
#         importancia experiencia cliente: donde 1 es lo mas importante y 4 no lo consideras importante  \
# count                                           69.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             1.956522
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              2.000000
# 75%                                              3.000000
# max                                              4.000000
# std                                              1.035187
#
#         importancia talento humano: donde 1 es lo mas importante y 4 no lo consideras importante  \
# count                                           69.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             2.739130
# min                                              1.000000
# 25%                                              2.000000
# 50%                                              3.000000
# 75%                                              3.000000
# max                                              4.000000
# std                                              1.009545
#
#         importancia tecnologia e innivación: donde 1 es lo mas importante y 4 no lo consideras importante  \
# count                                           69.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             3.115942
# min                                              1.000000
# 25%                                              2.000000
# 50%                                              3.000000
# 75%                                              4.000000
# max                                              4.000000
# std                                              0.978237
#
#                  amplia la importancia de atributos  ...  \
# count                                            68  ...
# unique                                           62  ...
# top     que den solucion y que no pierdan el tiempo  ...
# freq                                              3  ...
# mean                                            NaN  ...
# min                                             NaN  ...
# 25%                                             NaN  ...
# 50%                                             NaN  ...
# 75%                                             NaN  ...
# max                                             NaN  ...
# std                                             NaN  ...
#
#        Qué tan satisfecho estás con las alternativas dadas para tu solución?  \
# count                                                  70
# unique                                                  4
# top                                             Muy bueno
# freq                                                   37
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#        Qué tan satisfecho estás con los tiempo de solución ?  \
# count                                                  70
# unique                                                  4
# top                                             Muy bueno
# freq                                                   30
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#        Cómo calificas la importancia que  le damos a nuestros clientes?  \
# count                                                  70
# unique                                                  4
# top                                                 Bueno
# freq                                                   36
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#        Qué tan fácil fue obtener una solución?  \
# count                                       70
# unique                                       4
# top                                 Muy bueno
# freq                                        31
# mean                                       NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
# std                                        NaN
#
#        Que tan satisfecho estás con el conocimiento de nuestro personal?  \
# count                                                  70
# unique                                                  4
# top                                            Muy bueno
# freq                                                   36
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#        En la misma escala de 0 a 10, en caso que necesites nuevos servicios de consultoria, ¿Qué tan probable es que consideres a nuestra empresa como tu primera opción ? - Grupo  \
# count                                                  70
# unique                                                  3
# top                                              Promotor
# freq                                                   51
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#        En la misma escala de 0 a 10, en caso que necesites nuevos servicios de consultoria, ¿Qué tan probable es que consideres a nuestra empresa como tu primera opción ?  \
# count                                           70.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             8.742857
# min                                              1.000000
# 25%                                              8.000000
# 50%                                              9.000000
# 75%                                             10.000000
# max                                             10.000000
# std                                              1.799241
#
#        NPS: escala del 0 al 10, donde 0 es no lo recomendaría y 10 definitivamente sí lo recomendaria. Dinos qué tan probable es que recomiendes nuestros servicios  \
# count                                                  70
# unique                                                  3
# top                                              Promotor
# freq                                                   52
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#         NPS: En una escala de 0 a 10, donde 0 es la calificación más baja y 10 la más alta, ¿Qué tan probable es que recomiendes nuestros servicios?  \
# count                                           70.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             8.657143
# min                                              1.000000
# 25%                                              8.250000
# 50%                                              9.000000
# 75%                                             10.000000
# max                                             10.000000
# std                                              2.125659
#
#        Cuéntanos el motivo de tu calificación
# count                                      63
# unique                                     62
# top                  Innovación y excelencia.
# freq                                        2
# mean                                      NaN
# min                                       NaN
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                                       NaN
# std                                       NaN
#
# [11 rows x 22 columns]

# %%
# Miremos una descripción del set de datos con sus primeras filas.
datos.head()
# Out:
#                     Fecha  ID de respuesta Nombre del cliente Canal envio  \
# 0 2023-11-16 13:30:31.585                1          cliente 1       email
# 1 2023-11-16 14:54:57.335                2          cliente 2       email
# 2 2023-11-16 16:44:16.894                3          cliente 3       email
# 3 2023-11-17 16:47:18.235                4          cliente 4       email
# 4 2023-11-21 09:07:35.654                5          cliente 5       email
#
#   Idioma del usuario  \
# 0                 ES
# 1                 ES
# 2                 ES
# 3                 ES
# 4                 ES
#
#    importancia_conocimiento_de_marcas: donde 1 es lo mas importante y 4 no lo consideras importante  \
# 0                                                2.0
# 1                                                3.0
# 2                                                1.0
# 3                                                2.0
# 4                                                2.0
#
#    importancia experiencia cliente: donde 1 es lo mas importante y 4 no lo consideras importante  \
# 0                                                3.0
# 1                                                1.0
# 2                                                2.0
# 3                                                1.0
# 4                                                3.0
#
#    importancia talento humano: donde 1 es lo mas importante y 4 no lo consideras importante  \
# 0                                                4.0
# 1                                                2.0
# 2                                                4.0
# 3                                                3.0
# 4                                                1.0
#
#    importancia tecnologia e innivación: donde 1 es lo mas importante y 4 no lo consideras importante  \
# 0                                                1.0
# 1                                                4.0
# 2                                                3.0
# 3                                                4.0
# 4                                                4.0
#
#                   amplia la importancia de atributos  ...  \
# 0                           amabilidad y comprension  ...
# 1                                           cercania  ...
# 2                                        puntualidad  ...
# 3                                  servicios baratos  ...
# 4  cercania, calidez, centrado en el cliente, ama...  ...
#
#   Qué tan satisfecho estás con las alternativas dadas para tu solución?  \
# 0                                          Muy bueno
# 1                                          Muy bueno
# 2                                          Muy bueno
# 3                                          Muy bueno
# 4                                          Muy bueno
#
#   Qué tan satisfecho estás con los tiempo de solución ?  \
# 0                                          Muy bueno
# 1                                          Muy bueno
# 2                                              Bueno
# 3                                              Bueno
# 4                                          Muy bueno
#
#   Cómo calificas la importancia que  le damos a nuestros clientes?  \
# 0                                          Muy bueno
# 1                                          Muy bueno
# 2                                              Bueno
# 3                                              Bueno
# 4                                              Bueno
#
#   Qué tan fácil fue obtener una solución?  \
# 0                              Muy bueno
# 1                              Muy bueno
# 2                                 Regular
# 3                              Muy bueno
# 4                              Muy bueno
#
#   Que tan satisfecho estás con el conocimiento de nuestro personal?  \
# 0                                              Bueno
# 1                                         Muy bueno
# 2                                              Bueno
# 3                                              Bueno
# 4                                              Bueno
#
#   En la misma escala de 0 a 10, en caso que necesites nuevos servicios de consultoria, ¿Qué tan probable es que consideres a nuestra empresa como tu primera opción ? - Grupo  \
# 0                                           Promotor
# 1                                           Promotor
# 2                                             Pasivo
# 3                                             Pasivo
# 4                                           Promotor
#
#   En la misma escala de 0 a 10, en caso que necesites nuevos servicios de consultoria, ¿Qué tan probable es que consideres a nuestra empresa como tu primera opción ?  \
# 0                                                  9
# 1                                                 10
# 2                                                  8
# 3                                                  8
# 4                                                  9
#
#   NPS: escala del 0 al 10, donde 0 es no lo recomendaría y 10 definitivamente sí lo recomendaria. Dinos qué tan probable es que recomiendes nuestros servicios  \
# 0                                           Promotor
# 1                                           Promotor
# 2                                             Pasivo
# 3                                             Pasivo
# 4                                           Promotor
#
#    NPS: En una escala de 0 a 10, donde 0 es la calificación más baja y 10 la más alta, ¿Qué tan probable es que recomiendes nuestros servicios?  \
# 0                                                 10
# 1                                                 10
# 2                                                  7
# 3                                                  8
# 4                                                  9
#
#               Cuéntanos el motivo de tu calificación
# 0  Tienen las competencias y capacidades necesari...
# 1  siempre dispuestos a brindar la mejor asesoria...
# 2                                                NaN
# 3                  revisar relacion precio y calidad
# 4                                               bien
#
# [5 rows x 22 columns]

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 22 columns):
#  #   Column                                                                                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                                                                                       --------------  -----
#  0   Fecha                                                                                                                                                                        70 non-null     datetime64[ns]
#  1   ID de respuesta                                                                                                                                                              70 non-null     int64
#  2   Nombre del cliente                                                                                                                                                           70 non-null     object
#  3   Canal envio                                                                                                                                                                  70 non-null     object
#  4   Idioma del usuario                                                                                                                                                           70 non-null     object
#  5   importancia_conocimiento_de_marcas: donde 1 es lo mas importante y 4 no lo consideras importante                                                                             69 non-null     float64
#  6   importancia experiencia cliente: donde 1 es lo mas importante y 4 no lo consideras importante                                                                                69 non-null     float64
#  7   importancia talento humano: donde 1 es lo mas importante y 4 no lo consideras importante                                                                                     69 non-null     float64
#  8   importancia tecnologia e innivación: donde 1 es lo mas importante y 4 no lo consideras importante                                                                            69 non-null     float64
#  9   amplia la importancia de atributos                                                                                                                                           68 non-null     object
#  10  Cómo calificas los resultados entregados en las consultorías?                                                                                                                70 non-null     object
#  11  Cómo calificas la Metodología de desarrollo de los proyectos?                                                                                                                70 non-null     object
#  12  Qué tan satisfecho estás con las alternativas dadas para tu solución?                                                                                                        70 non-null     object
#  13  Qué tan satisfecho estás con los tiempo de solución ?                                                                                                                        70 non-null     object
#  14  Cómo calificas la importancia que  le damos a nuestros clientes?                                                                                                             70 non-null     object
#  15  Qué tan fácil fue obtener una solución?                                                                                                                                      70 non-null     object
#  16  Que tan satisfecho estás con el conocimiento de nuestro personal?                                                                                                            70 non-null     object
#  17  En la misma escala de 0 a 10, en caso que necesites nuevos servicios de consultoria, ¿Qué tan probable es que consideres a nuestra empresa como tu primera opción ? - Grupo  70 non-null     object
#  18  En la misma escala de 0 a 10, en caso que necesites nuevos servicios de consultoria, ¿Qué tan probable es que consideres a nuestra empresa como tu primera opción ?          70 non-null     int64
#  19  NPS: escala del 0 al 10, donde 0 es no lo recomendaría y 10 definitivamente sí lo recomendaria. Dinos qué tan probable es que recomiendes nuestros servicios                 70 non-null     object
#  20  NPS: En una escala de 0 a 10, donde 0 es la calificación más baja y 10 la más alta, ¿Qué tan probable es que recomiendes nuestros servicios?                                 70 non-null     int64
#  21  Cuéntanos el motivo de tu calificación                                                                                                                                       63 non-null     object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(14)
# memory usage: 12.2+ KB
